# %%
import pandas as pd

# %%
df = pd.read_csv('Around the world_sections.csv',encoding='utf-8')
df2 = pd.read_csv('One more time_sections.csv',encoding='utf-8')

# %%
ax = df[['start','loudness']].plot(figsize=(15,5), x='start', xlabel='TIME [S]',grid=True,style='--',c='#1DB954')
df2[['start','loudness']].plot(ax = ax,figsize=(15,5), x='start', xlabel='TIME [S]',grid=True,style='--',c='#FF5733')
# Out:
# <AxesSubplot:xlabel='TIME [S]'>

# %%
df2
# Out:
#              song      start  duration  confidence  loudness    tempo  \
# 0   One more time    0.00000  31.82924       1.000   -14.355  122.859
# 1   One more time   31.82924  26.36768       0.883    -8.525  122.803
# 2   One more time   58.19692  37.09930       0.845    -7.587  122.778
# 3   One more time   95.29622  10.25630       0.553    -8.167  122.897
# 4   One more time  105.55252  20.52114       0.247    -8.056  122.817
# 5   One more time  126.07365  15.66186       0.707    -6.976  122.912
# 6   One more time  141.73550  16.27265       0.544   -12.189  121.126
# 7   One more time  158.00816  21.54117       0.426   -12.194  121.922
# 8   One more time  179.54933  24.65409       0.969    -9.108  122.474
# 9   One more time  204.20341  13.19244       0.431    -9.655  124.356
# 10  One more time  217.39586  41.72947       0.372    -7.771  122.768
# 11  One more time  259.12534  29.54727       0.304    -8.266  123.389
# ...
